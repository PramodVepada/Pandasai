# %%
pip install pandasai
# Out:
# ...
#      -------------------------------------- 798.7/798.7 kB 3.0 MB/s eta 0:00:00
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#      ---------------------------------------- 7.6/7.6 MB 2.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 73.6/73.6 kB 2.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 319.8/319.8 kB 4.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.0
#     Uninstalling matplotlib-3.7.0:
#       Successfully uninstalled matplotlib-3.7.0
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.10.0
#     Uninstalling ipython-8.10.0:
#       Successfully uninstalled ipython-8.10.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pandasai import PandasAI
from pandasai.llm.openai import OpenAI

llm = OpenAI(api_token="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")

# %%
pandas_ai =  PandasAI(llm)

# %%
df = pd.read_csv('starbucks.csv')
df.drop("Unnamed: 0",axis = 1,inplace = True)

# %%
df
# Out:
#                                      item  calories   fat  carb  fiber  \
# 0                            8-Grain Roll       350   8.0    67      5
# 1                       Apple Bran Muffin       350   9.0    64      7
# 2                           Apple Fritter       420  20.0    59      0
# 3                         Banana Nut Loaf       490  19.0    75      4
# 4             Birthday Cake Mini Doughnut       130   6.0    17      0
# ..                                    ...       ...   ...   ...    ...
# 72        Tarragon Chicken Salad Sandwich       420  13.0    46      6
# 73                Turkey & Swiss Sandwich       390  13.0    36      2
# 74             Greek Yogurt Honey Parfait       300  12.0    44      0
# 75         Peach Raspberry Yogurt Parfait       300   4.0    57      3
# 76  Strawberry & Blueberry Yogurt Parfait       300   3.5    60      3
#
#     protein      type
# 0        10    bakery
# 1         6    bakery
# 2         5    bakery
# ...

# %%
response = pandas_ai.run(df,prompt = "What are the types of items available?")

# %%
response
# Out:
# array(['bakery', 'bistro box', 'petite', 'hot breakfast', 'salad',
#        'sandwich', 'parfait'], dtype=object)

# %%
response = pandas_ai.run(df,prompt = "which type of items have more calories")

# %%
response
# Out:
# type
# sandwich         395.714286
# bistro box       377.500000
# bakery           368.780488
# hot breakfast    325.000000
# parfait          300.000000
# petite           177.777778
# salad             80.000000
# Name: calories, dtype: float64

# %%
response = pandas_ai.run(df,prompt = "average calorie value of each type")

# %%
response
# Out:
# type
# bakery           368.780488
# bistro box       377.500000
# hot breakfast    325.000000
# parfait          300.000000
# petite           177.777778
# salad             80.000000
# sandwich         395.714286
# Name: calories, dtype: float64

# %%
response = pandas_ai.run(df,prompt = "Which items have more than 400 calories?")

# %%
response
# Out:
# 2                                    Apple Fritter
# 3                                  Banana Nut Loaf
# 6                                  Blueberry Scone
# 9                                    Cheese Danish
# 13                Chocolate Old-Fashioned Doughnut
# 15                             Cinnamon Chip Scone
# 16                          Cranberry Orange Scone
# 17                        Double Chocolate Brownie
# 21                           Iced Lemon Pound Cake
# 22                            Mallorca Sweet Bread
# 23                          Maple Oat Pecan Scone
# 28                   Old-Fashioned Glazed Doughnut
# 33                                  Pumpkin Scone
# 34                                 Raspberry Scone
# 35                      Raspberry Swirl Pound Cake
# 39                   Starbucks Classic Coffee Cake
# 40                         Zucchini Walnut Muffin
# 41                                  Cheese & Fruit
# ...

# %%
response = pandas_ai.run(df,prompt = "give me rows which have more than 400 calories")

# %%
response
# Out:
#                                             item  calories   fat  carb  fiber  \
# 2                                  Apple Fritter       420  20.0    59      0
# 3                                Banana Nut Loaf       490  19.0    75      4
# 6                                Blueberry Scone       460  22.0    61      2
# 9                                  Cheese Danish       420  25.0    39      0
# 13              Chocolate Old-Fashioned Doughnut       420  21.0    57      2
# 15                           Cinnamon Chip Scone       480  18.0    70      3
# 16                        Cranberry Orange Scone       490  18.0    73      2
# 17                      Double Chocolate Brownie       410  24.0    46      3
# 21                         Iced Lemon Pound Cake       490  23.0    67      0
# 22                          Mallorca Sweet Bread       420  25.0    42      0
# 23                        Maple Oat Pecan Scone        440  18.0    59      3
# ...

# %%
response = pandas_ai.run(df,prompt = "how many items of each type are available?")

# %%
response
# Out:
# type
# bakery           41
# bistro box        8
# hot breakfast     8
# parfait           3
# petite            9
# salad             1
# sandwich          7
# Name: item, dtype: int64

# %%
pandas_ai.run(df,prompt= 'visulaize the average calorie content in each type ')
